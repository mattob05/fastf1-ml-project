# %%
import numpy as np
import pandas as pd
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error
from sklearn.ensemble import RandomForestRegressor
import os

# %%
dir = os.getcwd()
project_root = os.path.abspath(os.path.join(dir, '..'))
data_root = os.path.join(project_root, 'data')
df = pd.read_csv(filepath_or_buffer=os.path.join(data_root, 'f1_data_cleaned.csv'))
df['Rainfall'] = df['Rainfall'].astype(int)

# %% [markdown]
# During the testing phase we will divide our dataset into training and testing set. For training we will take first 19 rounds, we will test on the other 5. Ultimately we will introduce Cross Validation.

# %%
df_train = df[df['RoundNumber'] < 20].copy()
df_test = df[df['RoundNumber'] >= 20].copy()

# %%
df_train
# Out:
#        DriverNumber  LapTime  LapNumber  SpeedST      Compound  TyreLife  \
# 0                 1   96.830        8.0    245.0  INTERMEDIATE       8.0
# 1                 4   96.278        8.0    276.0  INTERMEDIATE       8.0
# 2                81   97.251        8.0    257.0  INTERMEDIATE       8.0
# 3                 1   94.315        9.0    258.0  INTERMEDIATE       9.0
# 4                 4   94.638        9.0    281.0  INTERMEDIATE       9.0
# ...             ...      ...        ...      ...           ...       ...
# 17122            31   99.687       56.0    307.0        MEDIUM      32.0
# 17123            44  103.194       56.0    306.0          SOFT      27.0
# 17124            63   99.181       56.0    308.0          SOFT      26.0
# 17125            81   99.042       56.0    308.0          SOFT      29.0
# 17126            87   99.789       56.0    310.0          SOFT      29.0
#
#                   Team  TrackTemp  Rainfall  Position  RoundNumber  FuelLevel  \
# 0      Red Bull Racing       19.1         0       2.0            1       49.0
# 1              McLaren       19.1         0       1.0            1       49.0
# 2              McLaren       19.1         0       3.0            1       49.0
# 3      Red Bull Racing       19.1         0       2.0            1       48.0
# 4              McLaren       19.1         0       1.0            1       48.0
# ...                ...        ...       ...       ...          ...        ...
# 17122     Haas F1 Team       44.9         0      15.0           19        0.0
# 17123          Ferrari       44.9         0       4.0           19        0.0
# 17124         Mercedes       44.9         0       6.0           19        0.0
# 17125          McLaren       44.9         0       5.0           19        0.0
# 17126     Haas F1 Team       44.9         0       9.0           19        0.0
#
#        QualiBest    Target
# 0         75.096  1.289416
# 1         75.096  1.282066
# 2         75.096  1.295022
# 3         75.096  1.255926
# 4         75.096  1.260227
# ...          ...       ...
# 17122     92.510  1.077581
# 17123     92.510  1.115490
# 17124     92.510  1.072111
# 17125     92.510  1.070609
# 17126     92.510  1.078683
#
# [17127 rows x 14 columns]

# %% [markdown]
# Firstly I want to address the issue with recognizing drivers. We can leave it as it is, with numbers, but this would lead to inaccurate assumptions made by our model. One-hot encoding also doesn't seem like the best option (18 new columns!), so we will introduce new column: 'DriverPower'. We will calculate it by taking median of target results for every driver (only from training set).

# %%
median_targets = df_train.groupby('DriverNumber')['Target'].median()
df_train.loc[:, 'DriverPower'] = df_train['DriverNumber'].map(median_targets)
df_test.loc[:, 'DriverPower'] = df_test['DriverNumber'].map(median_targets)

# %%
df_train
# Out:
#        DriverNumber  LapTime  LapNumber  SpeedST      Compound  TyreLife  \
# 0                 1   96.830        8.0    245.0  INTERMEDIATE       8.0
# 1                 4   96.278        8.0    276.0  INTERMEDIATE       8.0
# 2                81   97.251        8.0    257.0  INTERMEDIATE       8.0
# 3                 1   94.315        9.0    258.0  INTERMEDIATE       9.0
# 4                 4   94.638        9.0    281.0  INTERMEDIATE       9.0
# ...             ...      ...        ...      ...           ...       ...
# 17122            31   99.687       56.0    307.0        MEDIUM      32.0
# 17123            44  103.194       56.0    306.0          SOFT      27.0
# 17124            63   99.181       56.0    308.0          SOFT      26.0
# 17125            81   99.042       56.0    308.0          SOFT      29.0
# 17126            87   99.789       56.0    310.0          SOFT      29.0
#
#                   Team  TrackTemp  Rainfall  Position  RoundNumber  FuelLevel  \
# 0      Red Bull Racing       19.1         0       2.0            1       49.0
# 1              McLaren       19.1         0       1.0            1       49.0
# 2              McLaren       19.1         0       3.0            1       49.0
# 3      Red Bull Racing       19.1         0       2.0            1       48.0
# 4              McLaren       19.1         0       1.0            1       48.0
# ...                ...        ...       ...       ...          ...        ...
# 17122     Haas F1 Team       44.9         0      15.0           19        0.0
# 17123          Ferrari       44.9         0       4.0           19        0.0
# 17124         Mercedes       44.9         0       6.0           19        0.0
# 17125          McLaren       44.9         0       5.0           19        0.0
# 17126     Haas F1 Team       44.9         0       9.0           19        0.0
#
#        QualiBest    Target  DriverPower
# 0         75.096  1.289416     1.076045
# 1         75.096  1.282066     1.076761
# 2         75.096  1.295022     1.077154
# 3         75.096  1.255926     1.076045
# 4         75.096  1.260227     1.076761
# ...          ...       ...          ...
# 17122     92.510  1.077581     1.096348
# 17123     92.510  1.115490     1.081338
# 17124     92.510  1.072111     1.082307
# 17125     92.510  1.070609     1.077154
# 17126     92.510  1.078683     1.096645
#
# [17127 rows x 15 columns]

# %% [markdown]
# Let's do the same thing for teams.

# %%
teams_median = df_train.groupby('Team')['Target'].median()
df_train.loc[:, 'TeamPace'] = df_train['Team'].map(teams_median)
df_test.loc[:, 'TeamPace'] = df_test['Team'].map(teams_median)
df_train = df_train.drop(columns='Team')
df_test = df_test.drop(columns='Team')

# %%
cat = ['Compound']
df_train.drop(columns=cat).corr()['Target'].sort_values(ascending=False)
# Out:
# Target          1.000000
# Rainfall        0.368297
# FuelLevel       0.319082
# DriverPower     0.166411
# TeamPace        0.147213
# Position        0.133670
# LapTime         0.012853
# DriverNumber    0.004130
# TyreLife       -0.037994
# TrackTemp      -0.118999
# RoundNumber    -0.155314
# LapNumber      -0.246556
# QualiBest      -0.269284
# SpeedST        -0.356408
# Name: Target, dtype: float64

# %% [markdown]
# Now, let's see if our score has improved

# %%
df_train.columns
# Out:
# Index(['DriverNumber', 'LapTime', 'LapNumber', 'SpeedST', 'Compound',
#        'TyreLife', 'TrackTemp', 'Rainfall', 'Position', 'RoundNumber',
#        'FuelLevel', 'QualiBest', 'Target', 'DriverPower', 'TeamPace'],
#       dtype='object')

# %%
df_train_eval = pd.get_dummies(df_train, columns=['Compound'])
df_test_eval = pd.get_dummies(df_test, columns=['Compound'])

# %%
col_to_drop = ['LapTime', 'DriverNumber', 'RoundNumber', 'LapNumber', 'Target', 'QualiBest']
X_train = df_train_eval.drop(columns=col_to_drop)
X_test = df_test_eval.drop(columns=col_to_drop)
y_train = df_train_eval['Target']
y_test = df_test_eval['Target']
X_test = X_test.reindex(columns=X_train.columns, fill_value=0)

# %%
model = RandomForestRegressor(
    n_estimators=100, 
    min_samples_leaf=10,
    max_depth=15,
    n_jobs=-1,
    max_features='sqrt',
    random_state=42
)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
y_pred = y_pred * df_test_eval['QualiBest']
mean_absolute_error(df_test_eval['LapTime'], y_pred)
# Out:
# 1.0328180963740117

# %% [markdown]
# Next we must address track diversity. Different tracks influence tyres differently, and have different length. We've prepared the dataset describing all tracks in 2025 calendar. For each track we have its length, what hardness are the different compounds (1-6) and columns: Traction, Abrasion, TrackEvolution, TyreStress, Lateral, Downforce. These values are important to the model, as they allow the model to understand differences in tyre degredation and speed on different tracks. Data was taken from official Pirelli information.

# %%
tracks = pd.read_csv(filepath_or_buffer=os.path.join(data_root, 'track_metadata_2025.csv'))
tracks = tracks.drop(columns='Location')

# %%
tyres = tracks[['RoundNumber', 'C_SOFT', 'C_MEDIUM', 'C_HARD']]
tyres
# Out:
#     RoundNumber  C_SOFT  C_MEDIUM  C_HARD
# 0             1       5         4       3
# 1             2       4         3       2
# 2             3       3         2       1
# 3             4       3         2       1
# 4             5       5         4       3
# 5             6       5         4       3
# 6             7       6         5       4
# 7             8       6         5       4
# 8             9       3         2       1
# 9            10       6         5       4
# 10           11       5         4       3
# 11           12       4         3       2
# 12           13       4         3       1
# 13           14       5         4       3
# 14           15       4         3       2
# 15           16       5         4       3
# 16           17       6         5       4
# 17           18       5         4       3
# 18           19       4         3       1
# 19           20       5         4       2
# 20           21       4         3       2
# 21           22       5         4       3
# 22           23       3         2       1
# 23           24       5         4       3

# %%
df_train['C_INTERMEDIATE'] = (df_train['Compound'] == 'INTERMEDIATE').astype(int)
df_test['C_INTERMEDIATE'] = (df_test['Compound'] == 'INTERMEDIATE').astype(int)

# %%
df_train = pd.merge(df_train, tracks, how='left', on='RoundNumber')
df_test = pd.merge(df_test, tracks, how='left', on='RoundNumber')

# %%
df_train
# Out:
#        DriverNumber  LapTime  LapNumber  SpeedST      Compound  TyreLife  \
# 0                 1   96.830        8.0    245.0  INTERMEDIATE       8.0
# 1                 4   96.278        8.0    276.0  INTERMEDIATE       8.0
# 2                81   97.251        8.0    257.0  INTERMEDIATE       8.0
# 3                 1   94.315        9.0    258.0  INTERMEDIATE       9.0
# 4                 4   94.638        9.0    281.0  INTERMEDIATE       9.0
# ...             ...      ...        ...      ...           ...       ...
# 17122            31   99.687       56.0    307.0        MEDIUM      32.0
# 17123            44  103.194       56.0    306.0          SOFT      27.0
# 17124            63   99.181       56.0    308.0          SOFT      26.0
# 17125            81   99.042       56.0    308.0          SOFT      29.0
# 17126            87   99.789       56.0    310.0          SOFT      29.0
#
#        TrackTemp  Rainfall  Position  RoundNumber  ...  Length  Traction  \
# 0           19.1         0       2.0            1  ...    5278         2
# 1           19.1         0       1.0            1  ...    5278         2
# 2           19.1         0       3.0            1  ...    5278         2
# 3           19.1         0       2.0            1  ...    5278         2
# 4           19.1         0       1.0            1  ...    5278         2
# ...          ...       ...       ...          ...  ...     ...       ...
# 17122       44.9         0      15.0           19  ...    5513         4
# 17123       44.9         0       4.0           19  ...    5513         4
# 17124       44.9         0       6.0           19  ...    5513         4
# 17125       44.9         0       5.0           19  ...    5513         4
# 17126       44.9         0       9.0           19  ...    5513         4
#
#        Abrasion  TrackEvolution  TyreStress  Lateral  Downforce  C_HARD  \
# 0             2               3           3        3          3       3
# 1             2               3           3        3          3       3
# 2             2               3           3        3          3       3
# 3             2               3           3        3          3       3
# 4             2               3           3        3          3       3
# ...         ...             ...         ...      ...        ...     ...
# 17122         3               4           4        4          4       1
# 17123         3               4           4        4          4       1
# 17124         3               4           4        4          4       1
# 17125         3               4           4        4          4       1
# 17126         3               4           4        4          4       1
#
#        C_MEDIUM  C_SOFT
# 0             4       5
# 1             4       5
# 2             4       5
# 3             4       5
# 4             4       5
# ...         ...     ...
# 17122         3       4
# 17123         3       4
# 17124         3       4
# 17125         3       4
# 17126         3       4
#
# [17127 rows x 26 columns]

# %%
def map_compound(df_to_map):
    df = df_to_map.copy()
    conditions = [
        df['Compound'] == 'SOFT',
        df['Compound'] == 'MEDIUM',
        df['Compound'] == 'HARD'
    ]

    choices = [
        df['C_SOFT'],
        df['C_MEDIUM'],
        df['C_HARD']
    ]

    df['CompoundRating'] = np.select(conditions, choices, default=0)
    return df['CompoundRating']

df_train['CompoundRating'] = map_compound(df_train)
df_test['CompoundRating'] = map_compound(df_test)
df_train
# Out:
#        DriverNumber  LapTime  LapNumber  SpeedST      Compound  TyreLife  \
# 0                 1   96.830        8.0    245.0  INTERMEDIATE       8.0
# 1                 4   96.278        8.0    276.0  INTERMEDIATE       8.0
# 2                81   97.251        8.0    257.0  INTERMEDIATE       8.0
# 3                 1   94.315        9.0    258.0  INTERMEDIATE       9.0
# 4                 4   94.638        9.0    281.0  INTERMEDIATE       9.0
# ...             ...      ...        ...      ...           ...       ...
# 17122            31   99.687       56.0    307.0        MEDIUM      32.0
# 17123            44  103.194       56.0    306.0          SOFT      27.0
# 17124            63   99.181       56.0    308.0          SOFT      26.0
# 17125            81   99.042       56.0    308.0          SOFT      29.0
# 17126            87   99.789       56.0    310.0          SOFT      29.0
#
#        TrackTemp  Rainfall  Position  RoundNumber  ...  Traction  Abrasion  \
# 0           19.1         0       2.0            1  ...         2         2
# 1           19.1         0       1.0            1  ...         2         2
# 2           19.1         0       3.0            1  ...         2         2
# 3           19.1         0       2.0            1  ...         2         2
# 4           19.1         0       1.0            1  ...         2         2
# ...          ...       ...       ...          ...  ...       ...       ...
# 17122       44.9         0      15.0           19  ...         4         3
# 17123       44.9         0       4.0           19  ...         4         3
# 17124       44.9         0       6.0           19  ...         4         3
# 17125       44.9         0       5.0           19  ...         4         3
# 17126       44.9         0       9.0           19  ...         4         3
#
#        TrackEvolution  TyreStress  Lateral  Downforce  C_HARD  C_MEDIUM  \
# 0                   3           3        3          3       3         4
# 1                   3           3        3          3       3         4
# 2                   3           3        3          3       3         4
# 3                   3           3        3          3       3         4
# 4                   3           3        3          3       3         4
# ...               ...         ...      ...        ...     ...       ...
# 17122               4           4        4          4       1         3
# 17123               4           4        4          4       1         3
# 17124               4           4        4          4       1         3
# 17125               4           4        4          4       1         3
# 17126               4           4        4          4       1         3
#
#        C_SOFT  CompoundRating
# 0           5               0
# 1           5               0
# 2           5               0
# 3           5               0
# 4           5               0
# ...       ...             ...
# 17122       4               3
# 17123       4               4
# 17124       4               4
# 17125       4               4
# 17126       4               4
#
# [17127 rows x 27 columns]

# %%
df_train = df_train.drop(columns=['C_HARD', 'C_MEDIUM', 'C_SOFT', 'Compound'])
df_test = df_test.drop(columns=['C_HARD', 'C_MEDIUM', 'C_SOFT', 'Compound'])

# %%
df_train[['Length', 'Traction', 'Abrasion', 'TrackEvolution', 'TyreStress', 'Lateral', 'Downforce', 'CompoundRating', 'Target']].corr()['Target']
# Out:
# Length           -0.153204
# Traction         -0.209839
# Abrasion          0.083242
# TrackEvolution   -0.361372
# TyreStress        0.098765
# Lateral           0.214855
# Downforce         0.251570
# CompoundRating   -0.463420
# Target            1.000000
# Name: Target, dtype: float64

# %%
df_train.corr()['Target'].sort_values(ascending=False)
# Out:
# Target            1.000000
# C_INTERMEDIATE    0.769402
# Rainfall          0.368297
# FuelLevel         0.319082
# Downforce         0.251570
# Lateral           0.214855
# DriverPower       0.166411
# TeamPace          0.147213
# Position          0.133670
# TyreStress        0.098765
# Abrasion          0.083242
# LapTime           0.012853
# DriverNumber      0.004130
# TyreLife         -0.037994
# TrackTemp        -0.118999
# Length           -0.153204
# RoundNumber      -0.155314
# Traction         -0.209839
# LapNumber        -0.246556
# QualiBest        -0.269284
# SpeedST          -0.356408
# TrackEvolution   -0.361372
# CompoundRating   -0.463420
# Name: Target, dtype: float64

# %% [markdown]
# Again, let's see if those changes improved our score

# %%
df_train_eval = df_train.copy()
df_test_eval = df_test.copy()

# %%
col_to_drop = ['LapTime', 'DriverNumber', 'RoundNumber', 'LapNumber', 'Target', 'QualiBest']
X_train = df_train_eval.drop(columns=col_to_drop)
X_test = df_test_eval.drop(columns=col_to_drop)
y_train = df_train_eval['Target']
y_test = df_test_eval['Target']
X_test = X_test.reindex(columns=X_train.columns, fill_value=0)

# %%
model = RandomForestRegressor(
    n_estimators=100, 
    min_samples_leaf=10,
    max_depth=15,
    n_jobs=-1,
    max_features='sqrt',
    random_state=42
)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
y_pred = y_pred * df_test_eval['QualiBest']
mae = mean_absolute_error(df_test_eval['LapTime'], y_pred)
mape = mean_absolute_percentage_error(df_test_eval['LapTime'], y_pred)
print(f'MAE: {mae}')
print(f'MAPE: {mape}')
# Out:
# MAE: 0.8470736241428554
# MAPE: 0.010513085062528585

# %% [markdown]
# Results are already promising, but let's see if we can improve that. Next step will be to add two important columns: GapAhead and GapBehind. They both can largely impact the race pace.

# %%
df_full = pd.read_csv(filepath_or_buffer=os.path.join(data_root, 'f1_data.csv'))

# saving position for next experiment
df_pos = df_full[['RoundNumber', 'LapNumber', 'DriverNumber', 'Position']]

# %%
df_full
# Out:
#                          Time Driver  DriverNumber                 LapTime  \
# 0      0 days 01:12:57.726000    NOR             4  0 days 00:01:57.099000
# 1      0 days 01:12:57.726000    DOO             7                     NaN
# 2      0 days 01:12:57.726000    HAD             6                     NaN
# 3      0 days 01:12:57.726000    SAI            55                     NaN
# 4      0 days 01:13:00.002000    VER             1  0 days 00:01:59.392000
# ...                       ...    ...           ...                     ...
# 24221  0 days 02:25:49.246000    BOR             5  0 days 00:01:30.667000
# 24222  0 days 02:25:50.361000    SAI            55  0 days 00:01:30.046000
# 24223  0 days 02:25:51.997000    TSU            22  0 days 00:01:29.566000
# 24224  0 days 02:25:52.602000    ANT            12  0 days 00:01:29.630000
# 24225  0 days 02:25:53.530000    ALB            23  0 days 00:01:29.256000
#
#        LapNumber  Stint  PitOutTime  PitInTime             Sector1Time  \
# 0            1.0    1.0         NaN        NaN                     NaN
# 1            1.0    1.0         NaN        NaN                     NaN
# 2            1.0    1.0         NaN        NaN                     NaN
# 3            1.0    1.0         NaN        NaN                     NaN
# 4            1.0    1.0         NaN        NaN                     NaN
# ...          ...    ...         ...        ...                     ...
# 24221       58.0    2.0         NaN        NaN  0 days 00:00:17.901000
# 24222       58.0    2.0         NaN        NaN  0 days 00:00:17.814000
# 24223       58.0    2.0         NaN        NaN  0 days 00:00:17.690000
# 24224       58.0    2.0         NaN        NaN  0 days 00:00:17.848000
# 24225       58.0    3.0         NaN        NaN  0 days 00:00:17.751000
#
#                   Sector2Time  ... TrackStatus Position Deleted DeletedReason  \
# 0      0 days 00:00:20.913000  ...         124      1.0   False           NaN
# 1                         NaN  ...         124      NaN   False           NaN
# 2                         NaN  ...         124      NaN   False           NaN
# 3                         NaN  ...         124      NaN   False           NaN
# 4      0 days 00:00:20.705000  ...         124      2.0   False           NaN
# ...                       ...  ...         ...      ...     ...           ...
# 24221  0 days 00:00:38.794000  ...           1     12.0   False           NaN
# 24222  0 days 00:00:38.404000  ...           1     13.0   False           NaN
# 24223  0 days 00:00:38.459000  ...           1     14.0   False           NaN
# 24224  0 days 00:00:37.897000  ...           1     15.0   False           NaN
# 24225  0 days 00:00:38.227000  ...           1     16.0   False           NaN
#
#        FastF1Generated  IsAccurate  TrackTemp  Rainfall WindSpeed RoundNumber
# 0                False       False       19.2     False       3.9           1
# 1                 True       False       19.2     False       3.9           1
# 2                 True       False       19.2     False       3.9           1
# 3                 True       False       19.2     False       3.9           1
# 4                False       False       19.2     False       3.9           1
# ...                ...         ...        ...       ...       ...         ...
# 24221            False        True       29.0     False       0.8          24
# 24222            False        True       29.0     False       0.8          24
# 24223            False        True       29.0     False       0.8          24
# 24224            False        True       29.0     False       0.8          24
# 24225            False        True       29.0     False       0.8          24
#
# [24226 rows x 35 columns]

# %%
df_full = df_full[['Time', 'DriverNumber', 'LapNumber', 'RoundNumber']].copy()
df_full['Time'] = pd.to_timedelta(df_full['Time'])
df_full = df_full.sort_values(by=['RoundNumber', 'LapNumber', 'Time'])

df_full['GapAhead'] = df_full.groupby(['RoundNumber', 'LapNumber'])['Time'].diff().dt.total_seconds()
df_full['GapBehind'] = df_full.groupby(['RoundNumber', 'LapNumber'])['GapAhead'].shift(-1)

df_full['GapAhead'] = df_full.groupby(['RoundNumber', 'DriverNumber'])['GapAhead'].shift(1)
df_full['GapBehind'] = df_full.groupby(['RoundNumber', 'DriverNumber'])['GapBehind'].shift(1)

df_full['GapAhead'] = df_full['GapAhead'].fillna(100.0)
df_full['GapBehind'] = df_full['GapBehind'].fillna(100.0)

# %%
df_full.describe()
# Out:
#                             Time  DriverNumber     LapNumber   RoundNumber  \
# count                      24226  24226.000000  24226.000000  24226.000000
# mean   0 days 01:47:42.013919095     29.469537     30.850037     12.336292
# std    0 days 00:30:29.788011497     24.894351     18.402908      6.691798
# min       0 days 00:56:41.841000      1.000000      1.000000      1.000000
# 25%       0 days 01:22:43.178750     10.000000     15.000000      7.000000
# 50%       0 days 01:46:19.063500     22.000000     30.000000     12.000000
# 75%       0 days 02:10:13.817500     44.000000     45.000000     18.000000
# max       0 days 03:41:30.238000     87.000000     78.000000     24.000000
#
#            GapAhead     GapBehind
# count  24226.000000  24226.000000
# mean      11.277579     11.210390
# std       26.070976     25.954906
# min        0.000000      0.000000
# 25%        0.977000      0.977000
# 50%        2.201000      2.203000
# 75%        5.702750      5.700250
# max      116.186000    116.186000

# %%
df_train.shape
# Out:
# (17127, 23)

# %%
df_full
# Out:
#                         Time  DriverNumber  LapNumber  RoundNumber  GapAhead  \
# 0     0 days 01:12:57.726000             4        1.0            1   100.000
# 1     0 days 01:12:57.726000             7        1.0            1   100.000
# 2     0 days 01:12:57.726000             6        1.0            1   100.000
# 3     0 days 01:12:57.726000            55        1.0            1   100.000
# 4     0 days 01:13:00.002000             1        1.0            1   100.000
# ...                      ...           ...        ...          ...       ...
# 24221 0 days 02:25:49.246000             5       58.0           24     4.882
# 24222 0 days 02:25:50.361000            55       58.0           24     1.205
# 24223 0 days 02:25:51.997000            22       58.0           24     2.116
# 24224 0 days 02:25:52.602000            12       58.0           24     0.541
# 24225 0 days 02:25:53.530000            23       58.0           24     1.302
#
#        GapBehind
# 0        100.000
# 1        100.000
# 2        100.000
# 3        100.000
# 4        100.000
# ...          ...
# 24221      0.531
# 24222      2.116
# 24223      0.541
# 24224      1.302
# 24225      5.256
#
# [24226 rows x 6 columns]

# %%
df_full = df_full.drop(columns=['Time'])
df_train = df_train.merge(df_full, how='inner', on=['RoundNumber', 'LapNumber', 'DriverNumber'])
df_test = df_test.merge(df_full, how='inner', on=['RoundNumber', 'LapNumber', 'DriverNumber'])
df_train
# Out:
#        DriverNumber  LapTime  LapNumber  SpeedST  TyreLife  TrackTemp  \
# 0                 1   96.830        8.0    245.0       8.0       19.1
# 1                 4   96.278        8.0    276.0       8.0       19.1
# 2                81   97.251        8.0    257.0       8.0       19.1
# 3                 1   94.315        9.0    258.0       9.0       19.1
# 4                 4   94.638        9.0    281.0       9.0       19.1
# ...             ...      ...        ...      ...       ...        ...
# 17122            31   99.687       56.0    307.0      32.0       44.9
# 17123            44  103.194       56.0    306.0      27.0       44.9
# 17124            63   99.181       56.0    308.0      26.0       44.9
# 17125            81   99.042       56.0    308.0      29.0       44.9
# 17126            87   99.789       56.0    310.0      29.0       44.9
#
#        Rainfall  Position  RoundNumber  FuelLevel  ...  Length  Traction  \
# 0             0       2.0            1       49.0  ...    5278         2
# 1             0       1.0            1       49.0  ...    5278         2
# 2             0       3.0            1       49.0  ...    5278         2
# 3             0       2.0            1       48.0  ...    5278         2
# 4             0       1.0            1       48.0  ...    5278         2
# ...         ...       ...          ...        ...  ...     ...       ...
# 17122         0      15.0           19        0.0  ...    5513         4
# 17123         0       4.0           19        0.0  ...    5513         4
# 17124         0       6.0           19        0.0  ...    5513         4
# 17125         0       5.0           19        0.0  ...    5513         4
# 17126         0       9.0           19        0.0  ...    5513         4
#
#        Abrasion  TrackEvolution  TyreStress  Lateral  Downforce  \
# 0             2               3           3        3          3
# 1             2               3           3        3          3
# 2             2               3           3        3          3
# 3             2               3           3        3          3
# 4             2               3           3        3          3
# ...         ...             ...         ...      ...        ...
# 17122         3               4           4        4          4
# 17123         3               4           4        4          4
# 17124         3               4           4        4          4
# 17125         3               4           4        4          4
# 17126         3               4           4        4          4
#
#        CompoundRating  GapAhead  GapBehind
# 0                   0     0.402      0.635
# 1                   0   100.000      0.402
# 2                   0     0.635      0.616
# 3                   0     0.954      1.056
# 4                   0   100.000      0.954
# ...               ...       ...        ...
# 17122               3     1.833     10.322
# 17123               4     9.969      5.294
# 17124               4     3.639     19.566
# 17125               4     5.294      3.639
# 17126               4     7.797      5.819
#
# [17127 rows x 25 columns]

# %% [markdown]
# Let's see if these features helped in reducing the error.

# %%
col_to_drop = ['LapTime', 'DriverNumber', 'RoundNumber', 'LapNumber', 'Target', 'QualiBest']
X_train = df_train.drop(columns=col_to_drop)
X_test = df_test.drop(columns=col_to_drop)
y_train = df_train['Target']
y_test = df_test['Target']
X_test = X_test.reindex(columns=X_train.columns, fill_value=0)

# %%
df_train.shape
# Out:
# (17127, 25)

# %%
(df_test_eval['QualiBest'] == df_test['QualiBest']).sum()
# Out:
# np.int64(4140)

# %%
df_test.shape
# Out:
# (4140, 25)

# %%
model = RandomForestRegressor(
    n_estimators=100, 
    min_samples_leaf=10,
    max_depth=15,
    n_jobs=-1,
    max_features='sqrt',
    random_state=42
)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
y_pred = y_pred * df_test['QualiBest']
mae = mean_absolute_error(df_test['LapTime'], y_pred)
mape = mean_absolute_percentage_error(df_test['LapTime'], y_pred)
print(f'MAE: {mae}')
print(f'MAPE: {mape}')
# Out:
# MAE: 0.7726168668886234
# MAPE: 0.009581783376684397

# %%
df_train.to_csv(os.path.join(data_root, 'f1_train.csv'), index=False)
df_test.to_csv(os.path.join(data_root, 'f1_test.csv'), index=False)
